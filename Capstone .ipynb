# %% [markdown]
# ## Extracting the Movie details from IBDM.com for Data analysis

# %%
#import all the packages
# !pip install bs4
# !pip install requests
import requests
from bs4 import BeautifulSoup
import pandas as pd
from time import sleep
from random import randint
from IPython.display import clear_output
import pandas as pd
import numpy as np

# %% [markdown]
# ### Checking the Random URls for some pages for selecting Base_URL

# %%
# # Lists to store the scraped data in
# Sno=[]
# movie_name = []
# Director_Name = []
# Duration=[]
# year= []
# ratings = []
# Metascore = []

# movie_no = 1
# for i in range(1,1000,50):
#   sleep(randint(2,5))
#   req = requests.get(Base_url+str(i)+'&ref_=adv_nxt',headers = {'Accept-Language':'en-US, en;q=0.5'})
#   soup = BeautifulSoup(req.text,'html')

#   if movie_no > 500:
#     break

#   #list of movies
#   movies_info = soup.findAll('div',attrs={'class':'lister-item-content'})

#   #loopin through each movie to collect details 
#   for movie in movies_info:

#     print(f'scrapping data of movie {movie_no}')
#     clear_output(wait=True)

#     movie_no += 1
    
#     #Movie name
#     movie_lst = movie.find('h3',attrs={'class':'lister-item-header'}).a.text
#     movie_name.append(movie_lst)

#     #Release year
#     Movie_releaseyear = soup.find('span',attrs ={'class':'lister-item-year text-muted unbold'}).text.replace('(','').replace(')','').strip()
#     releaseyear.append(Movie_releaseyear)
        
#     #certificate
#     certificate = movie.find('span',attrs={'class':'certificate'})
#     if certificate is None:
#       certificates.append("Not Available")
#     else:
#       certificates.append(certificate.text)
    
#     #duration
#     duration = movie.find('span',attrs={'class':'runtime'})
#     if duration is None:
#       durations.append("Not Available")
#     else:
#       durations.append(duration.text)


#     #genre
#     genre = movie.find('span',attrs={'class':'genre'})
#     if genre is None:
#       genres.append('Not Available')
#     else:
#       genres.append(genre.text.strip())

#     #IMBD
#     imbd = movie.find('div',attrs={'class':'inline-block ratings-imdb-rating'})
#     imdb_ratings.append(imbd.strong.text)

#     #metascore
#     metascore = movie.find('div',attrs={'class':'inline-block ratings-metascore'})
#     if metascore is None:
#       metascores.append("Not Available")
#     else:
#       metascores.append(metascore.span.text.strip())
  

#     #votes
#     vote = movie.find('span',attrs={'name':'nv'})
#     votes.append(vote.text)

# %%
#send request to fetch the  data of site
page=requests.get('https://www.imdb.com/search/title/?title_type=feature&num_votes=25000,&genres=action&sort=user_rating,desc')
page
# Out:
# <Response [200]>

# %%
#fetching the content of site
soup=BeautifulSoup(page.content)

# %%
pages=np.arange(1,1000,50)

# %%
Base_url=("https://www.imdb.com/search/title/?title_type=feature&num_votes=25000,&genres=action&sort=user_rating,desc&start=+str(page)+&ref_=adv_nxt")

# %%
movie_data=soup.find_all("div",attrs={"class":"lister-item mode-advanced"})

# %%
Sn=[]
movie_name = []
Director_Name = []
Duration=[]
year= []
ratings = []
Metascore = []

# %%
# for page in range(10, pages):
#     page=requests.get("https://www.imdb.com/search/title/?title_type=feature&num_votes=25000,&genres=action&sort=user_rating,desc&start=+str(page)+&ref_=adv_nxt")
#     soup = BeautifulSoup (page.text, 'html.parser')
#     sleep(randint (2,8))

# %%
for page in range(1,20):
    page=requests.get("https://www.imdb.com/search/title/?title_type=feature&num_votes=25000,&genres=action&sort=user_rating,desc&start=+str(page)+&ref_=adv_nxt")
    soup = BeautifulSoup (page.text, 'html.parser')
    sleep(randint (2,8))

# %%
movie_no = 1

for i in range(1,1000,50):
    sleep(randint(2,5))
    req = requests.get(Base_url+str(i)+'&ref_=adv_nxt',headers = {'Accept-Language':'en-US, en;q=0.5'})
    soup = BeautifulSoup(req.text,'html')

    if movie_no > 500:
        break

# %%
for store in movie_data:
    print(f'scrapping data of movie {movie_no}')
    clear_output(wait=True)

    movie_no += 1
    
    name = store.h3.a.text
    movie_name.append(name)
    year_of_release = store.h3.find('span', class_ = "lister-item-year text-muted unbold"). text.replace('(',' ').replace(')',' ')
    year.append (year_of_release)
    runtime = store.p.find("span", class_ = 'runtime')
    Duration.append(runtime.text)
    rate = store.find('div', class_ = "inline-block ratings-imdb-rating")
    ratings.append (rate.text.replace("\n"," "))
    meta = store.find('span', class_ ="metascore").text.replace(' ','') if store.find('span', class_ = "metascore") else "NA"
    Metascore.append (meta)
# Out:
# scrapping data of movie 50

# %%
# for i in soup.find_all('span',attrs={'class':'runtime'}):
#     Duration.append(i.text)

# %%
Duration
# Out:
# ['140 min',
#  '152 min',
#  '201 min',
#  '148 min',
#  '178 min',
#  '179 min',
#  '136 min',
#  '124 min',
#  '153 min',
#  '121 min',
#  '137 min',
#  '207 min',
#  '133 min',
#  '163 min',
#  '110 min',
#  '155 min',
#  '117 min',
#  '115 min',
#  '181 min',
#  '149 min',
#  '101 min',
#  '164 min',
#  '137 min',
#  '145 min',
#  '141 min',
#  '130 min',
#  '170 min',
#  '136 min',
#  '131 min',
#  '134 min',
#  '148 min',
#  '161 min',
#  '170 min',
#  '168 min',
#  '175 min',
#  '135 min',
#  '150 min',
#  '148 min',
#  '127 min',
#  '127 min',
#  '119 min',
#  '140 min',
#  '111 min',
#  '132 min',
#  '132 min',
#  '140 min',
#  '117 min',
#  '162 min',
#  '321 min',
#  '147 min']

# %%
genre = store.find('p', class_ = 'text-muted')
genre = genre.find('span', class_ = 'genre').string.strip() #genre list

# %%
genre
# Out:
# 'Action, Crime, Drama'

# %%
movie_name
# Out:
# ['Spider-Man: Across the Spider-Verse',
#  'The Dark Knight',
#  'The Lord of the Rings: The Return of the King',
#  'Inception',
#  'The Lord of the Rings: The Fellowship of the Ring',
#  'The Lord of the Rings: The Two Towers',
#  'The Matrix',
#  'Star Wars: Episode V - The Empire Strikes Back',
#  'Soorarai Pottru',
#  'Star Wars',
#  'Terminator 2: Judgment Day',
#  'Shichinin no samurai',
#  'Seppuku',
#  'Sita Ramam',
#  'Léon',
#  'Gladiator',
#  'Spider-Man: Into the Spider-Verse',
#  'Raiders of the Lost Ark',
#  'Avengers: Endgame',
#  'Avengers: Infinity War',
#  'Oldeuboi',
#  'The Dark Knight Rises',
#  'Aliens',
#  'Kaithi',
#  'Asuran',
#  'Top Gun: Maverick',
#  'Heat',
#  'North by Northwest',
#  'Star Wars: Episode VI - Return of the Jedi',
#  'Mononoke-hime',
#  'Kantara',
#  'Dangal',
#  'Ratsasan',
#  'K.G.F: Chapter 2',
#  'Vikram',
#  'Shershaah',
#  'Guardians of the Galaxy Vol. 3',
#  'Spider-Man: No Way Home',
#  'Jurassic Park',
# ...

# %%
year
# Out:
# [' 2023 ',
#  ' 2008 ',
#  ' 2003 ',
#  ' 2010 ',
#  ' 2001 ',
#  ' 2002 ',
#  ' 1999 ',
#  ' 1980 ',
#  ' 2020 ',
#  ' 1977 ',
#  ' 1991 ',
#  ' 1954 ',
#  ' 1962 ',
#  ' 2022 ',
#  ' 1994 ',
#  ' 2000 ',
#  ' 2018 ',
#  ' 1981 ',
#  ' 2019 ',
#  ' 2018 ',
#  ' 2003 ',
#  ' 2012 ',
#  ' 1986 ',
#  ' 2019 ',
#  ' 2019 ',
#  ' 2022 ',
#  ' 1995 ',
#  ' 1959 ',
#  ' 1983 ',
#  ' 1997 ',
#  ' 2022 ',
#  ' 2016 ',
#  ' 2018 ',
#  ' 2022 ',
#  ' 2022 ',
#  ' 2021 ',
#  ' 2023 ',
#  ' 2021 ',
#  ' 1993 ',
#  ' 1989 ',
#  ' 2019 ',
#  ' 2005 ',
#  ' 2003 ',
#  ' 1988 ',
#  ' 2005 ',
#  ' 2011 ',
#  ' 2020 ',
#  ' 1985 ',
#  ' 2012 ',
#  ' 2017 ']

# %%
ratings
# Out:
# ['  9.1 ',
#  '  9.0 ',
#  '  9.0 ',
#  '  8.8 ',
#  '  8.8 ',
#  '  8.8 ',
#  '  8.7 ',
#  '  8.7 ',
#  '  8.7 ',
#  '  8.6 ',
#  '  8.6 ',
#  '  8.6 ',
#  '  8.6 ',
#  '  8.6 ',
#  '  8.5 ',
#  '  8.5 ',
#  '  8.4 ',
#  '  8.4 ',
#  '  8.4 ',
#  '  8.4 ',
#  '  8.4 ',
#  '  8.4 ',
#  '  8.4 ',
#  '  8.4 ',
#  '  8.4 ',
#  '  8.3 ',
#  '  8.3 ',
#  '  8.3 ',
#  '  8.3 ',
#  '  8.3 ',
#  '  8.3 ',
#  '  8.3 ',
#  '  8.3 ',
#  '  8.3 ',
#  '  8.3 ',
#  '  8.3 ',
#  '  8.2 ',
#  '  8.2 ',
#  '  8.2 ',
#  '  8.2 ',
#  '  8.2 ',
#  '  8.2 ',
#  '  8.2 ',
#  '  8.2 ',
#  '  8.2 ',
#  '  8.2 ',
#  '  8.2 ',
#  '  8.2 ',
#  '  8.2 ',
#  '  8.2 ']

# %%
Metascore
# Out:
# ['86',
#  '84',
#  '94',
#  '74',
#  '92',
#  '87',
#  '73',
#  '82',
#  'NA',
#  '90',
#  '75',
#  '98',
#  '85',
#  'NA',
#  '64',
#  '67',
#  '87',
#  '85',
#  '78',
#  '68',
#  '77',
#  '78',
#  '84',
#  'NA',
#  'NA',
#  '78',
#  '76',
#  '98',
#  '58',
#  '76',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  '64',
#  '71',
#  '68',
#  '65',
#  '78',
#  '70',
#  '69',
#  '72',
#  '62',
#  '71',
#  '72',
#  '97',
#  '89',
#  'NA']

# %%
# number=store.find_all('span',class_="lister-item-index unbold text-primary")
# Sno.append(number.text.replace(' ',' '))

# %%
for i in soup.find_all('span',class_="lister-item-index unbold text-primary"):
    Sn.append(i.text.replace("\n"," ").split("(")[0])

# %%
# for i in soup.find_all('a',attrs={'class':'director'}):
#     Director_Name.append(i.text.replace("\n"," ").split("(")[0])

# %%
Director_Name
# Out:
# []

# %%
#for checking the Length
print(len(Sn),len(movie_name),len(year),len(ratings),len(Duration),len(Metascore))
# Out:
# 50 50 50 50 50 50

# %%
movie_df=pd.DataFrame({'Sno':Sn,'movie_name':movie_name,'year':year,'ratings':ratings,'Metascore':Metascore,'Duration':Duration})
movie_df
# Out:
#     Sno                                         movie_name    year ratings  \
# 0    1.                Spider-Man: Across the Spider-Verse   2023     9.1
# 1    2.                                    The Dark Knight   2008     9.0
# 2    3.      The Lord of the Rings: The Return of the King   2003     9.0
# 3    4.                                          Inception   2010     8.8
# 4    5.  The Lord of the Rings: The Fellowship of the Ring   2001     8.8
# 5    6.              The Lord of the Rings: The Two Towers   2002     8.8
# 6    7.                                         The Matrix   1999     8.7
# 7    8.     Star Wars: Episode V - The Empire Strikes Back   1980     8.7
# 8    9.                                    Soorarai Pottru   2020     8.7
# 9   10.                                          Star Wars   1977     8.6
# 10  11.                         Terminator 2: Judgment Day   1991     8.6
# 11  12.                               Shichinin no samurai   1954     8.6
# ...

# %%
# movie_df= movie_df.reset_index(drop=True)

# %%
movie_df.to_csv('movie_df.csv',header=False,index=False)

# %%
#Movie Name, stars, votes, Genre, Gross collection, popularity, Certification

# %%
# value = store.find_all('span', attrs = {'name': "nv"})  
#         vote = value [0]. text
#         votes.append(vote)
#         grosses = value [1].text if len (value)›1 else '*****'
#         gross.append(grosses)

# %%
# #scraping the no.
# Sno=[]
# for i in bsoup.find_all('span',class_="lister-item-index unbold text-primary"):
#     Sno.append(i.text)

# %%
# movie_name=[]
# for i in bsoup.find_all('h3',class_="lister-item-header"):
#     movie_name.append(i.text.replace("\n"," ").split("(")[0])
    
# movie_name

# %%
# Lists to store the scraped data in
movie_name = []
releaseyear = []
imdb_ratings = []
metascores = []
votes = []
certificates = []
durations = []
genres = []

movie_no = 1

for i in range(1,1000,50):
    sleep(randint(2,5))
    req = requests.get(Base_url+str(i)+'&ref_=adv_nxt',headers = {'Accept-Language':'en-US, en;q=0.5'})
    soup = BeautifulSoup(req.text,'html')

    if movie_no > 500:
        break

  #list of movies
movies_info = soup.find_all('div',attrs={'class':'lister-item-content'})

  #loopin through each movie to collect details 
for movie in movies_info:

    print(f'scrapping data of movie {movie_no}')
    clear_output(wait=True)

    movie_no += 1
     #Movie name
    movie_lst = movie.find('h3',attrs={'class':'lister-item-header'}).a.text
    movie_name.append(movie_lst)

    #Release year
    Movie_releaseyear = soup.find('span',attrs ={'class':'lister-item-year text-muted unbold'}).text.replace('(','').replace(')','').strip()
    releaseyear.append(Movie_releaseyear)
        
    #certificate
    certificate = movie.find('span',attrs={'class':'certificate'})
    if certificate is None:
        certificates.append("Not Available")
    else:
        certificates.append(certificate.text)
    
    #duration
    duration = movie.find('span',attrs={'class':'runtime'})
    if duration is None:
        durations.append("Not Available")
    else:
        durations.append(duration.text)
     #genre
    genre = movie.find('span',attrs={'class':'genre'})
    if genre is None:
        genres.append('Not Available')
    else:
        genres.append(genre.text.replace(',',' ').replace(',',' ').strip())
 
   
     #IMBD
    imbd = movie.find('div',attrs={'class':'inline-block ratings-imdb-rating'})
    imdb_ratings.append(imbd.strong.text)

    #metascore
    metascore = movie.find('div',attrs={'class':'inline-block ratings-metascore'})
    if metascore is None:
        metascores.append("Not Available")
    else:
        metascores.append(metascore.span.text.strip())

    vote = movie.find('span',attrs={'name':'nv'})
    votes.append(vote.text.replace(',',' ').replace(',',' '))
# Out:
# scrapping data of movie 50

# %%
#genre
genre = movie.find('span',attrs={'class':'genre'})
if genre is None:
    genres.append('Not Available')

# %%
movie_name
# Out:
# ['Spider-Man: Across the Spider-Verse',
#  'The Dark Knight',
#  'The Lord of the Rings: The Return of the King',
#  'Inception',
#  'The Lord of the Rings: The Fellowship of the Ring',
#  'The Lord of the Rings: The Two Towers',
#  'The Matrix',
#  'Star Wars: Episode V - The Empire Strikes Back',
#  'Soorarai Pottru',
#  'Star Wars: Episode IV - A New Hope',
#  'Terminator 2: Judgment Day',
#  'Seven Samurai',
#  'Harakiri',
#  'Sita Ramam',
#  'Léon: The Professional',
#  'Gladiator',
#  'Spider-Man: Into the Spider-Verse',
#  'Indiana Jones and the Raiders of the Lost Ark',
#  'Avengers: Endgame',
#  'Avengers: Infinity War',
#  'Oldboy',
#  'The Dark Knight Rises',
#  'Aliens',
#  'Kaithi',
#  'Asuran',
#  'Top Gun: Maverick',
#  'Heat',
#  'North by Northwest',
#  'Star Wars: Episode VI - Return of the Jedi',
#  'Princess Mononoke',
#  'Kantara',
#  'Dangal',
#  'Raatchasan',
#  'K.G.F: Chapter 2',
#  'Vikram',
#  'Shershaah',
#  'Guardians of the Galaxy Vol. 3',
# ...

# %%
releaseyear
# Out:
# ['2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023']

# %%
imdb_ratings
# Out:
# ['9.1',
#  '9.0',
#  '9.0',
#  '8.8',
#  '8.8',
#  '8.8',
#  '8.7',
#  '8.7',
#  '8.7',
#  '8.6',
#  '8.6',
#  '8.6',
#  '8.6',
#  '8.6',
#  '8.5',
#  '8.5',
#  '8.4',
#  '8.4',
#  '8.4',
#  '8.4',
#  '8.4',
#  '8.4',
#  '8.4',
#  '8.4',
#  '8.4',
#  '8.3',
#  '8.3',
#  '8.3',
#  '8.3',
#  '8.3',
#  '8.3',
#  '8.3',
#  '8.3',
#  '8.3',
#  '8.3',
#  '8.3',
#  '8.2',
#  '8.2',
#  '8.2',
#  '8.2',
#  '8.2',
#  '8.2',
#  '8.2',
#  '8.2',
#  '8.2',
#  '8.2',
#  '8.2',
#  '8.2',
#  '8.2',
#  '8.2']

# %%
metascores
# Out:
# ['86',
#  '84',
#  '94',
#  '74',
#  '92',
#  '87',
#  '73',
#  '82',
#  'Not Available',
#  '90',
#  '75',
#  '98',
#  '85',
#  'Not Available',
#  '64',
#  '67',
#  '87',
#  '85',
#  '78',
#  '68',
#  '77',
#  '78',
#  '84',
#  'Not Available',
#  'Not Available',
#  '78',
#  '76',
#  '98',
#  '58',
#  '76',
#  'Not Available',
#  'Not Available',
#  'Not Available',
#  'Not Available',
#  'Not Available',
#  'Not Available',
#  '64',
#  '71',
#  '68',
#  '65',
#  '78',
#  '70',
#  '69',
#  '72',
#  '62',
#  '71',
#  '72',
#  '97',
#  '89',
#  'Not Available']

# %%
votes
# Out:
# ['76 498',
#  '2 721 449',
#  '1 888 889',
#  '2 415 635',
#  '1 917 501',
#  '1 704 840',
#  '1 959 851',
#  '1 322 448',
#  '119 563',
#  '1 394 867',
#  '1 124 092',
#  '353 102',
#  '61 112',
#  '60 133',
#  '1 190 562',
#  '1 537 572',
#  '576 139',
#  '987 884',
#  '1 182 214',
#  '1 125 455',
#  '597 052',
#  '1 743 281',
#  '733 075',
#  '36 191',
#  '31 232',
#  '592 713',
#  '677 420',
#  '334 842',
#  '1 078 621',
#  '407 224',
#  '95 626',
#  '197 539',
#  '47 001',
#  '139 756',
#  '63 946',
#  '124 874',
#  '161 164',
#  '799 438',
#  '1 014 909',
#  '772 073',
#  '622 109',
#  '1 504 611',
#  '1 141 721',
#  '901 936',
#  '1 141 519',
#  '482 106',
#  '64 592',
#  '129 292',
#  '99 417',
#  '47 747']

# %%
certificates
# Out:
# ['PG',
#  'PG-13',
#  'PG-13',
#  'PG-13',
#  'PG-13',
#  'PG-13',
#  'R',
#  'PG',
#  'TV-MA',
#  'PG',
#  'R',
#  'Not Rated',
#  'Not Rated',
#  'U',
#  'R',
#  'R',
#  'PG',
#  'PG',
#  'PG-13',
#  'PG-13',
#  'R',
#  'PG-13',
#  'R',
#  'Not Rated',
#  'Not Rated',
#  'PG-13',
#  'R',
#  'Approved',
#  'PG',
#  'PG-13',
#  'Not Rated',
#  'Not Rated',
#  'Not Rated',
#  'Not Rated',
#  'UA',
#  'TV-14',
#  'PG-13',
#  'PG-13',
#  'PG-13',
#  'PG-13',
#  'R',
#  'PG-13',
#  'R',
#  'R',
#  'R',
#  'PG-13',
#  'R',
#  'R',
#  'Not Rated',
#  'Not Rated']

# %%
durations
# Out:
# ['140 min',
#  '152 min',
#  '201 min',
#  '148 min',
#  '178 min',
#  '179 min',
#  '136 min',
#  '124 min',
#  '153 min',
#  '121 min',
#  '137 min',
#  '207 min',
#  '133 min',
#  '163 min',
#  '110 min',
#  '155 min',
#  '117 min',
#  '115 min',
#  '181 min',
#  '149 min',
#  '101 min',
#  '164 min',
#  '137 min',
#  '145 min',
#  '141 min',
#  '130 min',
#  '170 min',
#  '136 min',
#  '131 min',
#  '134 min',
#  '148 min',
#  '161 min',
#  '170 min',
#  '168 min',
#  '175 min',
#  '135 min',
#  '150 min',
#  '148 min',
#  '127 min',
#  '127 min',
#  '119 min',
#  '140 min',
#  '111 min',
#  '132 min',
#  '132 min',
#  '140 min',
#  '117 min',
#  '162 min',
#  '321 min',
#  '147 min']

# %%
genres
# Out:
# ['Animation  Action  Adventure',
#  'Action  Crime  Drama',
#  'Action  Adventure  Drama',
#  'Action  Adventure  Sci-Fi',
#  'Action  Adventure  Drama',
#  'Action  Adventure  Drama',
#  'Action  Sci-Fi',
#  'Action  Adventure  Fantasy',
#  'Action  Drama',
#  'Action  Adventure  Fantasy',
#  'Action  Sci-Fi',
#  'Action  Drama',
#  'Action  Drama  Mystery',
#  'Action  Drama  Mystery',
#  'Action  Crime  Drama',
#  'Action  Adventure  Drama',
#  'Animation  Action  Adventure',
#  'Action  Adventure',
#  'Action  Adventure  Drama',
#  'Action  Adventure  Sci-Fi',
#  'Action  Drama  Mystery',
#  'Action  Drama  Thriller',
#  'Action  Adventure  Sci-Fi',
#  'Action  Adventure  Crime',
#  'Action  Drama',
#  'Action  Drama',
#  'Action  Crime  Drama',
#  'Action  Adventure  Mystery',
#  'Action  Adventure  Fantasy',
#  'Animation  Action  Adventure',
#  'Action  Adventure  Drama',
#  'Action  Biography  Drama',
#  'Action  Crime  Drama',
#  'Action  Crime  Drama',
# ...

# %%
metascores
# Out:
# ['86',
#  '84',
#  '94',
#  '74',
#  '92',
#  '87',
#  '73',
#  '82',
#  'Not Available',
#  '90',
#  '75',
#  '98',
#  '85',
#  'Not Available',
#  '64',
#  '67',
#  '87',
#  '85',
#  '78',
#  '68',
#  '77',
#  '78',
#  '84',
#  'Not Available',
#  'Not Available',
#  '78',
#  '76',
#  '98',
#  '58',
#  '76',
#  'Not Available',
#  'Not Available',
#  'Not Available',
#  'Not Available',
#  'Not Available',
#  'Not Available',
#  '64',
#  '71',
#  '68',
#  '65',
#  '78',
#  '70',
#  '69',
#  '72',
#  '62',
#  '71',
#  '72',
#  '97',
#  '89',
#  'Not Available']

# %%
# Gross_collection=[] 
# popularity=[]
# Gross= movie.find('span',attrs={'class':'lister-item-content'})
# for i in Gross:
#     print(i)
# #     name = i.div.h3.p.div.p.p.span.text
# # Gross_collection.append(name.text.replace(',',' ').replace(',',' '))

# %%
print(len(movie_name),len(releaseyear),len(ratings),len(durations),len(metascores),len(certificates),len(genres),len(imdb_ratings),len(votes))
# Out:
# 50 50 50 50 50 50 50 50 50

# %%
movie_data=pd.DataFrame({'movie_name':movie_name,'year':releaseyear,'ratings':ratings,'Metascore':metascores,'Certificate':certificates,'genres':genres,'imdb_ratings':imdb_ratings,'votes':votes,'durations':durations})
movie_data.drop(['movie_name','year','ratings','Metascore','Certificate','genres','imdb_ratings','votes','durations'], axis=1)
movie_data
# Out:
#                                            movie_name  year ratings  \
# 0                 Spider-Man: Across the Spider-Verse  2023    9.1
# 1                                     The Dark Knight  2023    9.0
# 2       The Lord of the Rings: The Return of the King  2023    9.0
# 3                                           Inception  2023    8.8
# 4   The Lord of the Rings: The Fellowship of the Ring  2023    8.8
# 5               The Lord of the Rings: The Two Towers  2023    8.8
# 6                                          The Matrix  2023    8.7
# 7      Star Wars: Episode V - The Empire Strikes Back  2023    8.7
# 8                                     Soorarai Pottru  2023    8.7
# 9                  Star Wars: Episode IV - A New Hope  2023    8.6
# 10                         Terminator 2: Judgment Day  2023    8.6
# 11                                      Seven Samurai  2023    8.6
# 12                                           Harakiri  2023    8.6
# ...

# %%
movie_data.to_csv('movie_d.csv',header=False, index=False)

# %%
# !pip install mysql-connector-python

# %%
import sqlite3

# %%
db=sqlite3.connect("new.db")

# %%
cursor=db.cursor()

# %%
cursor.execute("CREATE TABLE movie(Sno INT, movie_name, year, ratings, Metascore, Duration)")

# %%
s="Drop table movie"
cursor.execute(s)

# %%
with open ('movie_df.csv','r')as file:
    no_records=0
    for i in file:
        cursor.execute("insert into movie values(?,?,?,?,?,?)",i.split(","))
        db.commit()
        no_records+=1
    db.commit()
print(no_records,"Record inserted")
# Out:
# 50 Record inserted

# %%
# # cursor.execute("select*from movie")
# ALTER Table movie
# DROP COLUMN movie_name,year,ratings,Metascore,Certificate,genres,imdb_ratings,votes,durations;

# %%
results=cursor.execute("select*from movie")
for i in results:
    print(i)
# Out:
# (1, 'Spider-Man: Across the Spider-Verse', ' 2023 ', '  9.1 ', '86', '140 min\n')
# (2, 'The Dark Knight', ' 2008 ', '  9.0 ', '84', '152 min\n')
# (3, 'The Lord of the Rings: The Return of the King', ' 2003 ', '  9.0 ', '94', '201 min\n')
# (4, 'Inception', ' 2010 ', '  8.8 ', '74', '148 min\n')
# (5, 'The Lord of the Rings: The Fellowship of the Ring', ' 2001 ', '  8.8 ', '92', '178 min\n')
# (6, 'The Lord of the Rings: The Two Towers', ' 2002 ', '  8.8 ', '87', '179 min\n')
# (7, 'The Matrix', ' 1999 ', '  8.7 ', '73', '136 min\n')
# (8, 'Star Wars: Episode V - The Empire Strikes Back', ' 1980 ', '  8.7 ', '82', '124 min\n')
# (9, 'Soorarai Pottru', ' 2020 ', '  8.7 ', 'NA', '153 min\n')
# (10, 'Star Wars', ' 1977 ', '  8.6 ', '90', '121 min\n')
# (11, 'Terminator 2: Judgment Day', ' 1991 ', '  8.6 ', '75', '137 min\n')
# (12, 'Shichinin no samurai', ' 1954 ', '  8.6 ', '98', '207 min\n')
# (13, 'Seppuku', ' 1962 ', '  8.6 ', '85', '133 min\n')
# ...

# %%
import sqlite3
db=sqlite3.connect("new2.db")
cursor=db.cursor()

# %%
# Print I.split(,)

# %%
cursor.execute("CREATE TABLE movie_data2(movie_name TEXT,year INT,ratings,Metascore,Certificate,genres,imdb_ratings,votes,durations)")

# %%
s="Drop Table movie_data2"
cursor.execute(s)

# %%
with open ('movie_d.csv','r')as file:
    no_records=0
    for i in file:
#         print(i.split(','))
        cursor.execute("INSERT INTO movie_data2(movie_name,year,ratings,Metascore,Certificate,genres,imdb_ratings,votes,durations)values(?,?,?,?,?,?,?,?,?)",i.split(","))
        db.commit()
        no_records+=1
    db.commit()
print(no_records,"Record inserted")
# Out:
# 50 Record inserted

# %%
# print(I.split(,))

# %%
results=cursor.execute("select*from movie_data2")
for i in results:
    print(i)
# Out:
# ('Spider-Man: Across the Spider-Verse', 2023, '  9.1 ', '86', 'PG', 'Animation  Action  Adventure', '9.1', '76 498', '140 min\n')
# ('The Dark Knight', 2023, '  9.0 ', '84', 'PG-13', 'Action  Crime  Drama', '9.0', '2 721 449', '152 min\n')
# ('The Lord of the Rings: The Return of the King', 2023, '  9.0 ', '94', 'PG-13', 'Action  Adventure  Drama', '9.0', '1 888 889', '201 min\n')
# ('Inception', 2023, '  8.8 ', '74', 'PG-13', 'Action  Adventure  Sci-Fi', '8.8', '2 415 635', '148 min\n')
# ('The Lord of the Rings: The Fellowship of the Ring', 2023, '  8.8 ', '92', 'PG-13', 'Action  Adventure  Drama', '8.8', '1 917 501', '178 min\n')
# ('The Lord of the Rings: The Two Towers', 2023, '  8.8 ', '87', 'PG-13', 'Action  Adventure  Drama', '8.8', '1 704 840', '179 min\n')
# ('The Matrix', 2023, '  8.7 ', '73', 'R', 'Action  Sci-Fi', '8.7', '1 959 851', '136 min\n')
# ...

# %% [markdown]
# # Table 1:

# %% [markdown]
# ## Display all the details of movies with a duration of 140 minutes to 190 minutes.

# %%
result=cursor.execute("SELECT * FROM  movie where Duration between '140' and '190' ")
for i in results:
    print(i)
# Out:
# (1, 'Spider-Man: Across the Spider-Verse', ' 2023 ', '  9.1 ', '86', '140 min\n')
# (2, 'The Dark Knight', ' 2008 ', '  9.0 ', '84', '152 min\n')
# (4, 'Inception', ' 2010 ', '  8.8 ', '74', '148 min\n')
# (5, 'The Lord of the Rings: The Fellowship of the Ring', ' 2001 ', '  8.8 ', '92', '178 min\n')
# (6, 'The Lord of the Rings: The Two Towers', ' 2002 ', '  8.8 ', '87', '179 min\n')
# (9, 'Soorarai Pottru', ' 2020 ', '  8.7 ', 'NA', '153 min\n')
# (14, 'Sita Ramam', ' 2022 ', '  8.6 ', 'NA', '163 min\n')
# (16, 'Gladiator', ' 2000 ', '  8.5 ', '67', '155 min\n')
# (19, 'Avengers: Endgame', ' 2019 ', '  8.4 ', '78', '181 min\n')
# (20, 'Avengers: Infinity War', ' 2018 ', '  8.4 ', '68', '149 min\n')
# (22, 'The Dark Knight Rises', ' 2012 ', '  8.4 ', '78', '164 min\n')
# (24, 'Kaithi', ' 2019 ', '  8.4 ', 'NA', '145 min\n')
# (25, 'Asuran', ' 2019 ', '  8.4 ', 'NA', '141 min\n')
# (27, 'Heat', ' 1995 ', '  8.3 ', '76', '170 min\n')
# ...

# %% [markdown]
# # Display all details of movies with ratings above 7 in ascending order.

# %%
result1=cursor.execute("SELECT * FROM  movie where ratings >7")
for i in results:
    print(i)
# Out:
# ('Sno', 'movie_name', 'year', 'ratings', 'Metascore', 'Duration\n')
# (1, 'Spider-Man: Across the Spider-Verse', ' 2023 ', '  9.1 ', '86', '140 min\n')
# (2, 'The Dark Knight', ' 2008 ', '  9.0 ', '84', '152 min\n')
# (3, 'The Lord of the Rings: The Return of the King', ' 2003 ', '  9.0 ', '94', '201 min\n')
# (4, 'Inception', ' 2010 ', '  8.8 ', '74', '148 min\n')
# (5, 'The Lord of the Rings: The Fellowship of the Ring', ' 2001 ', '  8.8 ', '92', '178 min\n')
# (6, 'The Lord of the Rings: The Two Towers', ' 2002 ', '  8.8 ', '87', '179 min\n')
# (7, 'The Matrix', ' 1999 ', '  8.7 ', '73', '136 min\n')
# (8, 'Star Wars: Episode V - The Empire Strikes Back', ' 1980 ', '  8.7 ', '82', '124 min\n')
# (9, 'Soorarai Pottru', ' 2020 ', '  8.7 ', 'NA', '153 min\n')
# (10, 'Star Wars', ' 1977 ', '  8.6 ', '90', '121 min\n')
# (11, 'Terminator 2: Judgment Day', ' 1991 ', '  8.6 ', '75', '137 min\n')
# (12, 'Shichinin no samurai', ' 1954 ', '  8.6 ', '98', '207 min\n')
# ...

# %% [markdown]
# # Display all movie names in descending order

# %%
result2=cursor.execute("SELECT movie_name FROM  movie ORDER BY movie_name DESC")
for i in results:
    print(i)
# Out:
# ('movie_name',)
# ('Warrior',)
# ('Vikram Vedha',)
# ('Vikram',)
# ('V for Vendetta',)
# ('Top Gun: Maverick',)
# ('The Matrix',)
# ('The Lord of the Rings: The Two Towers',)
# ('The Lord of the Rings: The Return of the King',)
# ('The Lord of the Rings: The Fellowship of the Ring',)
# ('The Dark Knight Rises',)
# ('The Dark Knight',)
# ('Terminator 2: Judgment Day',)
# ('Star Wars: Episode VI - Return of the Jedi',)
# ('Star Wars: Episode V - The Empire Strikes Back',)
# ('Star Wars',)
# ('Spider-Man: No Way Home',)
# ('Spider-Man: Into the Spider-Verse',)
# ('Spider-Man: Across the Spider-Verse',)
# ('Soorarai Pottru',)
# ('Sita Ramam',)
# ('Shichinin no samurai',)
# ('Shershaah',)
# ('Seppuku',)
# ('Ratsasan',)
# ('Ran',)
# ('Raiders of the Lost Ark',)
# ('Oldeuboi',)
# ('North by Northwest',)
# ('Mononoke-hime',)
# ('LÃ©on',)
# ('Kimetsu no Yaiba: Mugen Ressha-Hen',)
# ('Kill Bill: Vol. 1',)
# ('Kantara',)
# ('Kaithi',)
# ('K.G.F: Chapter 2',)
# ('Jurassic Park',)
# ...

# %% [markdown]
# # Display movie name starts with ‘T’ and their rating is greater than 7

# %%
result3=cursor.execute("SELECT * FROM  movie WHERE movie_name like 'T%'and ratings >7  order by movie_name")
for i in results:
    print(i)
# Out:
# (11, 'Terminator 2: Judgment Day', ' 1991 ', '  8.6 ', '75', '137 min\n')
# (2, 'The Dark Knight', ' 2008 ', '  9.0 ', '84', '152 min\n')
# (22, 'The Dark Knight Rises', ' 2012 ', '  8.4 ', '78', '164 min\n')
# (5, 'The Lord of the Rings: The Fellowship of the Ring', ' 2001 ', '  8.8 ', '92', '178 min\n')
# (3, 'The Lord of the Rings: The Return of the King', ' 2003 ', '  9.0 ', '94', '201 min\n')
# (6, 'The Lord of the Rings: The Two Towers', ' 2002 ', '  8.8 ', '87', '179 min\n')
# (7, 'The Matrix', ' 1999 ', '  8.7 ', '73', '136 min\n')
# (26, 'Top Gun: Maverick', ' 2022 ', '  8.3 ', '78', '130 min\n')

# %% [markdown]
# # Table 2:

# %% [markdown]
# # Display all details of the movie with the highest number of votes.

# %%
result4=cursor.execute("SELECT movie_name,year,ratings,Metascore,Certificate,genres,imdb_ratings,durations,MAX(votes) AS SmallestPrice FROM movie_data2")
for i in results:
    print(i)
# Out:
# ('Gangs of Wasseypur', 2023, '  8.2 ', '89', 'Not Rated', 'Action  Comedy  Crime', '8.2', '321 min\n', '99 417')

# %% [markdown]
# # Display all details of movies with comedy and action genres

# %%
result5=cursor.execute("SELECT * FROM movie_data2 WHERE genres='Action  Comedy' ")
for i in results:
    print(i)

# %% [markdown]
# # Make subquery :

# %% [markdown]
# # Display all details from both tables where movie names are the same

# %%
result6=cursor.execute("SELECT * FROM movie INNER JOIN movie_data2 ON movie.movie_name = movie_data2.movie_name")
for i in results:
    print(i)
# Out:
# (1, 'Spider-Man: Across the Spider-Verse', ' 2023 ', '  9.1 ', '86', '140 min\n', 'Spider-Man: Across the Spider-Verse', 2023, '  9.1 ', '86', 'PG', 'Animation  Action  Adventure', '9.1', '76 498', '140 min\n')
# (2, 'The Dark Knight', ' 2008 ', '  9.0 ', '84', '152 min\n', 'The Dark Knight', 2023, '  9.0 ', '84', 'PG-13', 'Action  Crime  Drama', '9.0', '2 721 449', '152 min\n')
# (3, 'The Lord of the Rings: The Return of the King', ' 2003 ', '  9.0 ', '94', '201 min\n', 'The Lord of the Rings: The Return of the King', 2023, '  9.0 ', '94', 'PG-13', 'Action  Adventure  Drama', '9.0', '1 888 889', '201 min\n')
# (4, 'Inception', ' 2010 ', '  8.8 ', '74', '148 min\n', 'Inception', 2023, '  8.8 ', '74', 'PG-13', 'Action  Adventure  Sci-Fi', '8.8', '2 415 635', '148 min\n')
# ...

# %% [markdown]
# # Display all movie names, Director, ratings, and gross collection where the genre is action

# %%
result7=cursor.execute("SELECT movie_name,ratings,Metascore,Certificate,durations from movie_data2 WHERE genres ='Action'")
for i in results:
    print(i)

# %% [markdown]
# # Display all details from both tables with the highest ratings

# %%
result8=cursor.execute("SELECT * FROM movie  INNER JOIN movie_data2 ON movie.ratings = movie_data2.ratings")
for i in results:
    print(i)
# Out:
# (1, 'Spider-Man: Across the Spider-Verse', ' 2023 ', '  9.1 ', '86', '140 min\n', 'Spider-Man: Across the Spider-Verse', 2023, '  9.1 ', '86', 'PG', 'Animation  Action  Adventure', '9.1', '76 498', '140 min\n')
# (2, 'The Dark Knight', ' 2008 ', '  9.0 ', '84', '152 min\n', 'The Dark Knight', 2023, '  9.0 ', '84', 'PG-13', 'Action  Crime  Drama', '9.0', '2 721 449', '152 min\n')
# (2, 'The Dark Knight', ' 2008 ', '  9.0 ', '84', '152 min\n', 'The Lord of the Rings: The Return of the King', 2023, '  9.0 ', '94', 'PG-13', 'Action  Adventure  Drama', '9.0', '1 888 889', '201 min\n')
# (3, 'The Lord of the Rings: The Return of the King', ' 2003 ', '  9.0 ', '94', '201 min\n', 'The Dark Knight', 2023, '  9.0 ', '84', 'PG-13', 'Action  Crime  Drama', '9.0', '2 721 449', '152 min\n')
# ...

# %% [markdown]
# # Now once completed with queries in the SQLite database, then make the exact query solutions by using PANDAS SQL in the data frame.  Load the CSV data in a data frame and start making solutions for all the above 15 queries using PANDAS SQL. You may use concat or merge joins per the requirements basis to make 5 join queries.

# %%
result=cursor.execute("select * from movie")
# for i in result:
#     print(i)
df= pd.DataFrame(result.fetchall())
results=cursor.execute("select*from movie_data2")
data=pd.DataFrame(results.fetchall())

# %%
col=["Sno","movie_name","year" ,"ratings","Metascore","durations"]

# %%
df.columns=col

# %%
df
# Out:
#     Sno                                         movie_name    year  ratings  \
# 0   Sno                                         movie_name    year  ratings
# 1     1                Spider-Man: Across the Spider-Verse   2023      9.1
# 2     2                                    The Dark Knight   2008      9.0
# 3     3      The Lord of the Rings: The Return of the King   2003      9.0
# 4     4                                          Inception   2010      8.8
# 5     5  The Lord of the Rings: The Fellowship of the Ring   2001      8.8
# 6     6              The Lord of the Rings: The Two Towers   2002      8.8
# 7     7                                         The Matrix   1999      8.7
# 8     8     Star Wars: Episode V - The Empire Strikes Back   1980      8.7
# 9     9                                    Soorarai Pottru   2020      8.7
# 10   10                                          Star Wars   1977      8.6
# ...

# %%
df.drop([0], axis=0, inplace=True)

# %%
df
# Out:
#    Sno                                         movie_name    year ratings  \
# 1    1                Spider-Man: Across the Spider-Verse   2023     9.1
# 2    2                                    The Dark Knight   2008     9.0
# 3    3      The Lord of the Rings: The Return of the King   2003     9.0
# 4    4                                          Inception   2010     8.8
# 5    5  The Lord of the Rings: The Fellowship of the Ring   2001     8.8
# 6    6              The Lord of the Rings: The Two Towers   2002     8.8
# 7    7                                         The Matrix   1999     8.7
# 8    8     Star Wars: Episode V - The Empire Strikes Back   1980     8.7
# 9    9                                    Soorarai Pottru   2020     8.7
# 10  10                                          Star Wars   1977     8.6
# 11  11                         Terminator 2: Judgment Day   1991     8.6
# 12  12                               Shichinin no samurai   1954     8.6
# ...

# %%
column=["movie_name","year","ratings","Metascore","Certificate","genres","imdb_ratings","votes","durations"]

# %%
data.columns=column

# %%
data
# Out:
#                                            movie_name  year ratings  \
# 0                 Spider-Man: Across the Spider-Verse  2023    9.1
# 1                                     The Dark Knight  2023    9.0
# 2       The Lord of the Rings: The Return of the King  2023    9.0
# 3                                           Inception  2023    8.8
# 4   The Lord of the Rings: The Fellowship of the Ring  2023    8.8
# 5               The Lord of the Rings: The Two Towers  2023    8.8
# 6                                          The Matrix  2023    8.7
# 7      Star Wars: Episode V - The Empire Strikes Back  2023    8.7
# 8                                     Soorarai Pottru  2023    8.7
# 9                  Star Wars: Episode IV - A New Hope  2023    8.6
# 10                         Terminator 2: Judgment Day  2023    8.6
# 11                                      Seven Samurai  2023    8.6
# 12                                           Harakiri  2023    8.6
# ...
